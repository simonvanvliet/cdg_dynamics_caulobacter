# %%
import pathlib
import delta.config as cfg
from delta.utilities import xpreader
from delta.pipeline import Pipeline
import tensorflow as tf

# %%
dev = tf.config.list_physical_devices()
print(dev)

def to_str(posixpath):
    return str(posixpath.resolve())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#set paths
root_processed = pathlib.Path(pathlib.Path.home(), 'switchdrive', 'Biozentrum', 'Andreas')


data_dir = pathlib.Path('/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/')

#create output dir
output_root = root_processed / 'extra_data_Cc'
(output_root).mkdir(exist_ok=True) #create output data folder,  each position will be placed in a subfolder

#get config file
config_file = root_processed / 'config_2D_caulobacter.json'
cfg.load_config(config_file)
cfg.model_file_seg = to_str(root_processed / 'models' / 'unet_caulobacter2d_seg.hdf5') 
cfg.save_format = ('pickle','movie')

#find subfolders
folder_names = [f.name for f in sorted(data_dir.glob('AKS*'))]
# Out:
# Loading configuration from: /Users/simonvanvliet/switchdrive/Biozentrum/Andreas/config_2D_caulobacter.json

# %%
folder_names
# Out:
# ['AKS1179', 'AKS1180', 'AKS1181', 'AKS1182', 'AKS1183', 'AKS1184']

# %%
for folder in folder_names:
    #get images in subfolder
    movie_names = [f.name for f in sorted((data_dir / folder).glob('*.tif*'))]

    #create output subfolder
    output_path = output_root / folder
    (output_path).mkdir(exist_ok=True) #create output data folder,  each position will be placed in a subfolder

    for movie in movie_names:        
        #path to current position
        movie_dir = data_dir / folder / movie
        
        #make nickname of movei (adapt to file name structure, here we take the part starting at TL and stopping before __R3D)
        start = movie.find('TL')
        end = movie.find('_R3D', start)
        movie_name_short = movie[start:end] + '_s2'
        
        #make subfolder for current position
        output_dir = output_path / movie_name_short
        (output_dir).mkdir(exist_ok=True)

        try:  
            print('starting with movie %s->%s' %(folder,movie_name_short)) 
            # Init reader (use bioformats=True if working with nd2, czi, ome-tiff etc):
            im_reader = xpreader(movie_dir, use_bioformats=True)

            # Print experiment parameters to make sure it initialized properly:
            print("""Initialized experiment reader:
                - %d positions
                - %d imaging channels
                - %d timepoints"""%(im_reader.positions, im_reader.channels, im_reader.timepoints)
            )

            # Init pipeline:
            xp = Pipeline(im_reader, resfolder=to_str(output_dir))   

            # Run pipeline
            xp.process()
            
        except:
            print('error with movie %s->%s, skipping to next' %(folder,movie_name_short))
# Out:
# starting with movie AKS1179->TL_01_01_s2
# 11:35:12.311 [Thread-1] DEBUG loci.common.NIOByteBufferProvider - Using mapped byte buffer? false
# 11:35:12.343 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.345 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.345 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.345 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.578 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 11:35:12.578 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 11:35:12.578 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 11:35:12.578 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 11:35:12.610 [Thread-1] DEBUG o.s.nativelib.NativeLibraryUtil - processor is UNKNOWN os.arch is aarch64
# 11:35:12.610 [Thread-1] DEBUG o.s.nativelib.NativeLibraryUtil - architecture is UNKNOWN os.name is mac os x
# 11:35:12.610 [Thread-1] WARN  o.s.nativelib.NativeLibraryUtil - No native library available for this platform.
# 11:35:12.674 [Thread-1] DEBUG loci.common.services.ServiceFactory - Loaded properties from: services.properties
# 11:35:12.674 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface ome.codecs.services.JAIIIOService and implementation class ome.codecs.services.JAIIIOServiceImpl
# 11:35:12.674 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JPEGXRService and implementation class loci.formats.services.JPEGXRServiceImpl
# 11:35:12.675 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.LuraWaveService and implementation class loci.formats.services.LuraWaveServiceImpl
# 11:35:12.675 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.MDBService and implementation class loci.formats.services.MDBServiceImpl
# 11:35:12.675 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.MetakitService and implementation class loci.formats.services.MetakitServiceImpl
# 11:35:12.676 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.EXIFService and implementation class loci.formats.services.EXIFServiceImpl
# 11:35:12.676 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JHDFService and implementation class loci.formats.services.JHDFServiceImpl
# 11:35:12.676 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.WlzService and implementation class loci.formats.services.WlzServiceImpl
# 11:35:12.677 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.NetCDFService and implementation class loci.formats.services.NetCDFServiceImpl
# 11:35:12.677 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JAIIIOService and implementation class loci.formats.services.JAIIIOServiceImpl
# 11:35:12.678 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.OMEXMLService and implementation class loci.formats.services.OMEXMLServiceImpl
# 11:35:12.678 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.POIService and implementation class loci.formats.services.POIServiceImpl
# 11:35:12.678 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.common.services.S3ClientService and implementation class loci.common.services.S3ClientServiceImpl
# 11:35:12.678 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JPEGTurboService and implementation class loci.formats.services.JPEGTurboServiceImpl
# 11:35:12.678 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface ome.codecs.services.LuraWaveService and implementation class ome.codecs.services.LuraWaveServiceImpl
# 11:35:12.699 [Thread-1] DEBUG loci.formats.FormatHandler - TiffReader initializing /Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_01_R3D-1.tif
# 11:35:12.699 [Thread-1] DEBUG loci.formats.FormatHandler - loci.formats.in.TiffReader.initFile(/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_01_R3D-1.tif)
# 11:35:12.702 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Reading IFDs
# 11:35:12.792 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Populating metadata
# 11:35:12.799 [Thread-1] INFO  loci.formats.in.TiffReader - Checking comment style
# 11:35:12.820 [Thread-1] INFO  loci.formats.in.BaseTiffReader - Populating OME metadata
# 11:35:12.829 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.830 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.830 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.830 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:35:12.863 [Thread-1] DEBUG loci.formats.FormatHandler - TiffReader initializing /Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_01_R3D-1.tif
# 11:35:12.864 [Thread-1] DEBUG loci.formats.FormatHandler - loci.formats.in.TiffReader.initFile(/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_01_R3D-1.tif)
# 11:35:12.864 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Reading IFDs
# 11:35:12.879 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Populating metadata
# 11:35:12.881 [Thread-1] INFO  loci.formats.in.TiffReader - Checking comment style
# 11:35:12.931 [Thread-1] INFO  loci.formats.in.BaseTiffReader - Populating OME metadata
# Initialized experiment reader:
#                 - 1 positions
#                 - 3 imaging channels
#                 - 112 timepoints
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Wed Aug 24 11:35:16 2022, Position 0 - Starting pre-processing
# Wed Aug 24 11:35:16 2022, Position 0 - Starting segmentation (112 frames)
# 64/64 [==============================] - 11s 151ms/step
# 64/64 [==============================] - 10s 148ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 10s 155ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 9s 147ms/step
# 64/64 [==============================] - 10s 153ms/step
# 64/64 [==============================] - 10s 152ms/step
# 64/64 [==============================] - 10s 151ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 10s
[Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.190 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.191 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.191 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.232 [Thread-1] DEBUG loci.formats.FormatHandler - TiffReader initializing /Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_02_R3D-1.tif
# 11:53:04.232 [Thread-1] DEBUG loci.formats.FormatHandler - loci.formats.in.TiffReader.initFile(/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_02_R3D-1.tif)
# 11:53:04.232 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Reading IFDs
# 11:53:04.275 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Populating metadata
# 11:53:04.276 [Thread-1] INFO  loci.formats.in.TiffReader - Checking comment style
# 11:53:04.286 [Thread-1] INFO  loci.formats.in.BaseTiffReader - Populating OME metadata
# 11:53:04.292 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.292 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.292 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.292 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 11:53:04.317 [Thread-1] DEBUG loci.formats.FormatHandler - TiffReader initializing /Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_02_R3D-1.tif
# 11:53:04.317 [Thread-1] DEBUG loci.formats.FormatHandler - loci.formats.in.TiffReader.initFile(/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc/AKS1179/20220819_Caulo_NewSetwithUJ508etc_TL_01_02_R3D-1.tif)
# 11:53:04.317 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Reading IFDs
# 11:53:04.329 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Populating metadata
# 11:53:04.330 [Thread-1] INFO  loci.formats.in.TiffReader - Checking comment style
# 11:53:04.356 [Thread-1] INFO  loci.formats.in.BaseTiffReader - Populating OME metadata
# Initialized experiment reader:
#                 - 1 positions
#                 - 3 imaging channels
#                 - 95 timepoints
# Wed Aug 24 11:53:06 2022, Position 0 - Starting pre-processing
# Wed Aug 24 11:53:06 2022, Position 0 - Starting segmentation (95 frames)
# 64/64 [==============================] - 10s 155ms/step
# 64/64 [==============================] - 9s 148ms/step
# 64/64 [==============================] - 10s 150ms/step
# 64/64 [==============================] - 10s 150ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 10s 150ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 10s 149ms/step
# 64/64 [==============================] - 10s 152ms/step
# 64/64 [==============================] - 9s 146ms/step
# 64/64 [==============================] - 10s 151ms/step
# 64/64 [==============================] - 9s 147ms/step
# 23/23 [==============================] - 4s 155ms/step
# Wed Aug 24 11:55:27 2022, Position 0 - Starting tracking (95 frames)
# Wed Aug 24 11:55:27 2022, Position 0 - Tracking - frame 0/95
# Wed Aug 24 11:55:27 2022, Position 0 - Tracking - frame 1/95
# Wed Aug 24 11:55:28 2022, Position 0 - Tracking - frame 2/95
# Wed Aug 24 11:55:29 2022, Position 0 - Tracking - frame 3/95
# Wed Aug 24 11:55:30 2022, Position 0 - Tracking - frame 4/95
# Wed Aug 24 11:55:31 2022, Position 0 - Tracking - frame 5/95
# Wed Aug 24 11:55:32 2022, Position 0 - Tracking - frame 6/95
# Wed Aug 24 11:55:33 2022, Position 0 - Tracking - frame 7/95
# Wed Aug 24 11:55:34 2022, Position 0 - Tracking - frame 8/95
