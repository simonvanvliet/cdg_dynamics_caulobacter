# %%
import pathlib
import delta.config as cfg
from delta.utilities import xpreader
from delta.pipeline import Pipeline
import tensorflow as tf

# %%
dev = tf.config.list_physical_devices()
print(dev)

def to_str(posixpath):
    return str(posixpath.resolve())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#set paths
root_processed = pathlib.Path(pathlib.Path.home(), 'switchdrive', 'Biozentrum', 'Andreas')


data_dir = pathlib.Path('/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc_Fast/')

#create output dir
output_root = root_processed / 'extra_data_Cc_Fast'
(output_root).mkdir(exist_ok=True) #create output data folder,  each position will be placed in a subfolder

#get config file
config_file = root_processed / 'config_2D_caulobacter.json'
cfg.load_config(config_file)
cfg.model_file_seg = to_str(root_processed / 'models' / 'unet_caulobacter2d_seg.hdf5') 
cfg.save_format = ('pickle','movie')

#find subfolders
folder_names = [f.name for f in sorted(data_dir.glob('AKS*'))]
# Out:
# Loading configuration from: /Users/simonvanvliet/switchdrive/Biozentrum/Andreas/config_2D_caulobacter.json

# %%
folder_names
# Out:
# ['AKS1092']

# %%
for folder in folder_names:
    #get images in subfolder
    movie_names = [f.name for f in sorted((data_dir / folder).glob('*.tif*'))]

    #create output subfolder
    output_path = output_root / folder
    (output_path).mkdir(exist_ok=True) #create output data folder,  each position will be placed in a subfolder

    for movie in movie_names:        
        #path to current position
        movie_dir = data_dir / folder / movie
        
        #make nickname of movei (adapt to file name structure, here we take the part starting at TL and stopping before __R3D)
        start = movie.find('TL')
        end = movie.find('_R3D', start)
        movie_name_short = movie[start:end] + '_s2'
        
        #make subfolder for current position
        output_dir = output_path / movie_name_short
        (output_dir).mkdir(exist_ok=True)

        try:  
            print('starting with movie %s->%s' %(folder,movie_name_short)) 
            # Init reader (use bioformats=True if working with nd2, czi, ome-tiff etc):
            im_reader = xpreader(movie_dir, use_bioformats=True)

            # Print experiment parameters to make sure it initialized properly:
            print("""Initialized experiment reader:
                - %d positions
                - %d imaging channels
                - %d timepoints"""%(im_reader.positions, im_reader.channels, im_reader.timepoints)
            )

            # Init pipeline:
            xp = Pipeline(im_reader, resfolder=to_str(output_dir))   

            # Run pipeline
            xp.process()
            
        except:
            print('error with movie %s->%s, skipping to next' %(folder,movie_name_short))
# Out:
# starting with movie AKS1092->TL_01_1_s2
# 12:10:40.578 [Thread-1] DEBUG loci.common.NIOByteBufferProvider - Using mapped byte buffer? false
# 12:10:40.592 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:40.594 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:40.594 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:40.594 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:40.794 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 12:10:40.794 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 12:10:40.794 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 12:10:40.794 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:122) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ImageReader.getDefaultReaderClasses(ImageReader.java:80) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.in.FilePatternReader.<init>(FilePatternReader.java:67) ~[bioformats_package.jar:6.6.0]
# 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:67) ~[na:na]
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499) ~[na:na]
# 	at java.base/java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[na:na]
# 	at java.base/jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:341) ~[na:na]
# 	at java.base/java.lang.Class.newInstance(Class.java:677) ~[na:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:131) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:577) ~[na:na]
# 	at org.mozilla.javascript.MemberBox.invoke(MemberBox.java:126) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.NativeJavaMethod.call(NativeJavaMethod.java:225) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.optimizer.OptRuntime.callProp0(OptRuntime.java:85) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1._c_script_0(<java-python-bridge>:6) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.ContextFactory.doTopCall(ContextFactory.java:394) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.ScriptRuntime.doTopCall(ScriptRuntime.java:3091) ~[rhino-1.7R4.jar:1.7R4]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.call(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.gen._java_python_bridge__1.exec(<java-python-bridge>) ~[na:na]
# 	at org.mozilla.javascript.Context.evaluateString(Context.java:1079) ~[rhino-1.7R4.jar:1.7R4]
# 12:10:40.820 [Thread-1] DEBUG o.s.nativelib.NativeLibraryUtil - processor is UNKNOWN os.arch is aarch64
# 12:10:40.820 [Thread-1] DEBUG o.s.nativelib.NativeLibraryUtil - architecture is UNKNOWN os.name is mac os x
# 12:10:40.820 [Thread-1] WARN  o.s.nativelib.NativeLibraryUtil - No native library available for this platform.
# 12:10:40.882 [Thread-1] DEBUG loci.common.services.ServiceFactory - Loaded properties from: services.properties
# 12:10:40.882 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface ome.codecs.services.JAIIIOService and implementation class ome.codecs.services.JAIIIOServiceImpl
# 12:10:40.882 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JPEGXRService and implementation class loci.formats.services.JPEGXRServiceImpl
# 12:10:40.882 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.LuraWaveService and implementation class loci.formats.services.LuraWaveServiceImpl
# 12:10:40.883 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.MDBService and implementation class loci.formats.services.MDBServiceImpl
# 12:10:40.883 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.MetakitService and implementation class loci.formats.services.MetakitServiceImpl
# 12:10:40.883 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.EXIFService and implementation class loci.formats.services.EXIFServiceImpl
# 12:10:40.883 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JHDFService and implementation class loci.formats.services.JHDFServiceImpl
# 12:10:40.884 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.WlzService and implementation class loci.formats.services.WlzServiceImpl
# 12:10:40.884 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.NetCDFService and implementation class loci.formats.services.NetCDFServiceImpl
# 12:10:40.884 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JAIIIOService and implementation class loci.formats.services.JAIIIOServiceImpl
# 12:10:40.885 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.OMEXMLService and implementation class loci.formats.services.OMEXMLServiceImpl
# 12:10:40.885 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.POIService and implementation class loci.formats.services.POIServiceImpl
# 12:10:40.885 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.common.services.S3ClientService and implementation class loci.common.services.S3ClientServiceImpl
# 12:10:40.885 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface loci.formats.services.JPEGTurboService and implementation class loci.formats.services.JPEGTurboServiceImpl
# 12:10:40.885 [Thread-1] DEBUG loci.common.services.ServiceFactory - Added interface interface ome.codecs.services.LuraWaveService and implementation class ome.codecs.services.LuraWaveServiceImpl
# 12:10:40.907 [Thread-1] DEBUG loci.formats.FormatHandler - TiffReader initializing /Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc_Fast/AKS1092/20220816_FastImaging_AKS1092_inclREFscarchannel_20sec_TL_01_1_R3D.tif
# 12:10:40.908 [Thread-1] DEBUG loci.formats.FormatHandler - loci.formats.in.TiffReader.initFile(/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc_Fast/AKS1092/20220816_FastImaging_AKS1092_inclREFscarchannel_20sec_TL_01_1_R3D.tif)
# 12:10:40.910 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Reading IFDs
# 12:10:41.079 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Populating metadata
# 12:10:41.086 [Thread-1] INFO  loci.formats.in.TiffReader - Checking comment style
# 12:10:41.123 [Thread-1] INFO  loci.formats.in.BaseTiffReader - Populating OME metadata
# 12:10:41.137 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.URLReader
# java.lang.ClassNotFoundException: loci.formats.in.URLReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:41.137 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.SlideBook6Reader
# java.lang.ClassNotFoundException: loci.formats.in.SlideBook6Reader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:41.137 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ScreenReader
# java.lang.ClassNotFoundException: loci.formats.in.ScreenReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:41.137 [Thread-1] DEBUG loci.formats.ClassList - Could not find loci.formats.in.ZarrReader
# java.lang.ClassNotFoundException: loci.formats.in.ZarrReader
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:521) ~[na:na]
# 	at java.base/java.lang.Class.forName0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:383) ~[na:na]
# 	at java.base/java.lang.Class.forName(Class.java:376) ~[na:na]
# 	at loci.formats.ClassList.parseLine(ClassList.java:196) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.parseFile(ClassList.java:258) ~[bioformats_package.jar:6.6.0]
# 	at loci.formats.ClassList.<init>(ClassList.java:138) ~[bioformats_package.jar:6.6.0]
# 12:10:41.174 [Thread-1] DEBUG loci.formats.FormatHandler - TiffReader initializing /Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc_Fast/AKS1092/20220816_FastImaging_AKS1092_inclREFscarchannel_20sec_TL_01_1_R3D.tif
# 12:10:41.174 [Thread-1] DEBUG loci.formats.FormatHandler - loci.formats.in.TiffReader.initFile(/Volumes/RG-UJ01-Data01/Andreas/NewDataSimon/Cc_Fast/AKS1092/20220816_FastImaging_AKS1092_inclREFscarchannel_20sec_TL_01_1_R3D.tif)
# 12:10:41.174 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Reading IFDs
# 12:10:41.194 [Thread-1] INFO  loci.formats.in.MinimalTiffReader - Populating metadata
# 12:10:41.197 [Thread-1] INFO  loci.formats.in.TiffReader - Checking comment style
# 12:10:41.282 [Thread-1] INFO  loci.formats.in.BaseTiffReader - Populating OME metadata
